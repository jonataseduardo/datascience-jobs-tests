# %% [markdown]
# ## Jonatas Cesar

# %% [markdown]
# ### Objective
# The task is develop an unsupervised model which classifies abstracts into a topic.
# Indeed, the goal is to group abstracts based on their semantic similarity.

# %% [markdown]
# ### Download documents and install dependencies

# %%
# %%capture
# !pip install bertopic lxml

# %%
# %%capture
# %%sh 
mkdir data
wget https://www.nsf.gov/awardsearch/download\?DownloadFileName\=2020\&All\=true -O temp.zip
unzip -d data temp.zip
rm temp.zip

# %% [markdown]
# ## Resolution of the task

# %%
# %%capture
from pathlib import Path

import lxml.etree as ET
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from bertopic.vectorizers import ClassTfidfTransformer
from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP

# %%
def get_abstract_from_xml(xml_path: str) -> str:
    try:
        tree = ET.parse(xml_path)
        abstract_html = str(tree.find(".//AbstractNarration").text)
        abstract = abstract_html.replace("&lt;br/&gt;", "")
        return abstract
    except Exception as e:
        print("Error: ", e)

# %%
files = sorted(Path("data").rglob("*.xml"))
abstracts = [_ for _ in [get_abstract_from_xml(str(f)) for f in files] if _ != "None"]

# %%
# Step 1 - Extract embeddings (
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Step 2 - Reduce dimensionality
umap_model = UMAP(n_neighbors=30, n_components=5, min_dist=0.0, metric="cosine")

# Step 3 - Cluster reduced embeddings
hdbscan_model = HDBSCAN(
    min_cluster_size=50,
    metric="euclidean",
    cluster_selection_method="eom",
    prediction_data=True,
)

# Step 4 - Tokenize topics
vectorizer_model = CountVectorizer(stop_words="english", ngram_range=(1, 3), min_df = 30, max_df=0.9)

# Step 5 - Create topic representation
ctfidf_model = ClassTfidfTransformer()

# Step 6 -  Fine-tune topic representations with
# `bertopic.representation` model
representation_model = KeyBERTInspired()

# All steps together
topic_model = BERTopic(
    embedding_model=embedding_model,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    vectorizer_model=vectorizer_model,
    ctfidf_model=ctfidf_model,
    representation_model=representation_model,
    top_n_words=10,
)

# %%
topics, probs = topic_model.fit_transform(abstracts)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   5735            -1_molecular_chemistry_chemical_devices
# 1       0    592          0_matter_discoveries_physics_observations
# 2       1    549                  1_surface_phenomena_shape_physics
# 3       2    461  2_stem education_education research_stem field...
# 4       3    369     3_climate_simulations_project use_observations
# 5       4    352            4_molecular_biology_biological_pathways
# 6       5    341                  5_regions_depth_ground_structural
# 7       6    338             6_ecosystem_climate_chemistry_chemical
# 8       7    296             7_species_ecosystem_biology_biological
# 9       8    251  8_machine learning_deep learning_algorithms_da...
# 10      9    222         9_proposed project_devices_device_hardware
# 11     10    214  10_gas_proposed project_chemistry_science engi...
# 12     11    209              11_chemistry_electronic_matter_phases
# 13     12    208           12_water_sustainability_ecosystem_sensor
# 14     13    203                    13_covid_risks_concerns_threats
# 15     14    187                  14_3d_mechanical_industrial_shape
# 16     15    135  15_project explores_ecosystem_sustainability_e...
# 17     16    130     16_recruit_stem education_recruitment_academia
# 18     17    129                17_covid_policies_predicting_spread
# 19     18    124            18_mechanical_tasks_coordination_assist
# 20     19    114                19_autonomous_ai_robustness_sensing
# 21     20    113                       20_covid_air_surface_exposed
# 22     21    111  21_stem education_mentorship_stem fields_under...
# 23     22    111        22_spectrum_frequency_communications_signal
# 24     23    111  23_computer science_programming_computing_curr...
# 25     24    106               24_covid_laboratory_detect_detection
# 26     25    106  25_computing_computation_algorithms_computer s...
# 27     26    101                 26_covid_molecular_biology_disease
# 28     27     96          27_programming_computing_code_open source
# 29     28     95    28_hardware_high performance_scalable_computing
# 30     29     94        29_storage_electronic_chemistry_sustainable
# 31     30     90               30_biological_biology_stress_pathway
# 32     31     86             31_ai_computer science_protect_threats
# 33     32     85  32_technological_curriculum_industrial_workfor...
# 34     33     85              33_climate_air_chemistry_observations
# 35     34     81            34_language_communicate_contexts_native
# 36     35     73               35_ecosystem_climate_water_landscape
# 37     36     73            36_climate_ecosystem_stakeholders_north
# 38     37     67       37_cluster_computing_campus_computer science
# 39     38     67  38_conferences_conference_computer science_com...
# 40     39     63  39_resilience_resilient_sustainability_vulnerable
# 41     40     63           40_protocols_databases_private_computing
# 42     41     62  41_engineering mathematics_students project_cl...
# 43     42     60                    42_neural_thinking_attention_ai
#
#                                        Representation  \
# 0   [molecular, chemistry, chemical, devices, data...
# 1   [matter, discoveries, physics, observations, m...
# 2   [surface, phenomena, shape, physics, mathemati...
# 3   [stem education, education research, stem fiel...
# 4   [climate, simulations, project use, observatio...
# 5   [molecular, biology, biological, pathways, pat...
# 6   [regions, depth, ground, structural, boundarie...
# 7   [ecosystem, climate, chemistry, chemical, post...
# 8   [species, ecosystem, biology, biological, evol...
# 9   [machine learning, deep learning, algorithms, ...
# 10  [proposed project, devices, device, hardware, ...
# 11  [gas, proposed project, chemistry, science eng...
# 12  [chemistry, electronic, matter, phases, molecu...
# 13  [water, sustainability, ecosystem, sensor, sus...
# 14  [covid, risks, concerns, threats, resilience, ...
# 15  [3d, mechanical, industrial, shape, designs, m...
# 16  [project explores, ecosystem, sustainability, ...
# 17  [recruit, stem education, recruitment, academi...
# 18  [covid, policies, predicting, spread, policy, ...
# 19  [mechanical, tasks, coordination, assist, safe...
# 20  [autonomous, ai, robustness, sensing, safety, ...
# 21  [covid, air, surface, exposed, protection, dis...
# 22  [stem education, mentorship, stem fields, unde...
# 23  [spectrum, frequency, communications, signal, ...
# 24  [computer science, programming, computing, cur...
# 25  [covid, laboratory, detect, detection, detecti...
# 26  [computing, computation, algorithms, computer ...
# 27  [covid, molecular, biology, disease, biologica...
# 28  [programming, computing, code, open source, vu...
# 29  [hardware, high performance, scalable, computi...
# 30  [storage, electronic, chemistry, sustainable, ...
# 31  [biological, biology, stress, pathway, pathway...
# 32  [ai, computer science, protect, threats, vulne...
# 33  [technological, curriculum, industrial, workfo...
# 34  [climate, air, chemistry, observations, chemic...
# 35  [language, communicate, contexts, native, tran...
# 36  [ecosystem, climate, water, landscape, storage...
# 37  [climate, ecosystem, stakeholders, north, inte...
# 38  [cluster, computing, campus, computer science,...
# 39  [conferences, conference, computer science, co...
# 40  [resilience, resilient, sustainability, vulner...
# 41  [protocols, databases, private, computing, sca...
# 42  [engineering mathematics, students project, cl...
# 43  [neural, thinking, attention, ai, representati...
#
#                                   Representative_Docs
# 0   [The maturation of energy-harvesting (EH) tech...
# 1   [There are astrophysical objects named neutron...
# 2   [This research addresses problems emerging fro...
# 3   [Morgan State University proposes to implement...
# 4   [The geological history of tropical glaciers c...
# 5   [One of the great challenges of modern science...
# 6   [There is a 99.7% chance a magnitude 6.7 earth...
# 7   [Dissolved organic carbon (DOC) is a key compo...
# 8   [Species are a fundamental unit of diversity i...
# 9   [Exciting empirical breakthroughs have emerged...
# 10  [The broader impact/commercial potential of th...
# 11  [Methane is the primary component of natural g...
# 12  [NONTECHNICAL SUMMARYThis CAREER award support...
# 13  [After leaving water treatment facilities, dri...
# 14  [The study will integrate survey, social media...
# 15  [NONTECHNICAL SUMMARYAdditive manufacturing, a...
# 16  [This project examines how the spread of agric...
# 17  [Salish Kootenai College (SKC), in collaborati...
# 18  [Controlling COVID-19 infections in prison is ...
# 19  [Worker fatigue increases the risk for illness...
# 20  [Consider two future autonomous system use-cas...
# 21  [The broader impact/commercial potential of th...
# 22  [This project will contribute to the national ...
# 23  [Wireless systems with different radio access ...
# 24  [Computation has become standard within profes...
# 25  [COVID-19 has caused tens of thousands of deat...
# 26  [Nontechnical SummaryThis award is made on an ...
# 27  [The COVID-19 pandemic is caused by the SARS-C...
# 28  [srcML is an infrastructure for the exploratio...
# 29  [This project is developing techniques that ca...
# 30  [Transportation accounts for 28% of energy-rel...
# 31  [Stresses such as herbivore or pathogen attack...
# 32  [Artificial intelligence (AI) has significant ...
# 33  [According to the International Federation of ...
# 34  [This project aims to improve understanding of...
# 35  [A central goal of cognitive science is to und...
# 36  [Accurate modeling of water storage and fluxes...
# 37  [Navigating the New Arctic (NNA) is one of NSF...
# 38  [New usage patterns of computing for research ...
# 39  [The Association for Computing Machinery (ACM)...
# 40  [This Disaster Resilience Research Grant (DRRG...
# 41  [Nowadays, vast amounts of individual informat...
# 42  [Students bring many mathematical assets to th...
# 43  [The ability to reason about the relations bet...

# %%
embeddings = embedding_model.encode(abstracts, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/412 [00:00<?, ?it/s]

# %%
# Reduce outliers with pre-calculate embeddings instead
new_topics = topic_model.reduce_outliers(abstracts, topics, strategy="embeddings", embeddings=embeddings)
topic_model.update_topics(abstracts, topics=new_topics)

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_hierarchy()

# %%
umap_model_plot = UMAP(n_neighbors=30, n_components=2, min_dist=0.0, metric="cosine")
reduced_embeddings = umap_model_plot.fit_transform(embeddings)

# %%
topic_model.visualize_documents(
    abstracts, reduced_embeddings=reduced_embeddings, hide_annotations=True, sample = 0.1
)
